# %%
import os
os.chdir("..")

# %%
import syndalib.syndalib.src.synth as synth
import matplotlib.pyplot as plt

# %%
my_circles = synth.circles(ns=40, 
                           radius=2, 
                           center=(5,2), 
                           n=100, 
                           noise_perc=0.4, 
                           outliers_perc=0.2, 
                           homogeneous=False)
my_circles
# Out:
# array([[[ 4.05874413,  0.36442375],
#         [ 6.56554638,  1.00167022],
#         [ 4.83117349,  0.98671449],
#         ...,
#         [ 7.35735072,  2.76481846],
#         [ 4.36867729,  4.24692436],
#         [ 3.55016409,  0.92948015]],
#
#        [[ 3.94260726,  1.72963906],
#         [ 3.72016671,  1.90478845],
#         [ 4.71975349,  0.07750144],
#         ...,
#         [ 3.48670731,  1.61981204],
#         [ 4.9459604 ,  3.72262251],
#         [ 6.24626712, -0.16490768]],
#
#        [[ 6.07240857,  1.45205275],
#         [ 4.65749213,  0.35774467],
#         [ 5.02764701, -0.30207896],
#         ...,
#         [ 6.45335102,  4.15999344],
#         [ 3.24023697,  0.76290556],
#         [ 2.58669951,  2.11332483]],
#
#        ...,
#
#        [[ 4.70809155,  0.39131375],
#         [ 3.19236853,  0.38766191],
#         [ 6.4184686 ,  1.63280109],
#         ...,
#         [ 5.83489116,  3.930577  ],
#         [ 2.78039994,  1.83802607],
#         [ 7.07978559,  1.50192205]],
#
# ...

# %%
my_circle = my_circles[0]
my_circle
# Out:
# array([[ 4.72135158e+00,  3.77967629e+00],
#        [ 7.13215840e+00,  1.82803475e+00],
#        [ 3.50622724e+00,  1.58198474e+00],
#        [ 5.50786030e+00,  2.61284483e+00],
#        [ 4.58687090e+00,  2.25395289e-01],
#        [ 6.76806203e+00,  2.51486063e+00],
#        [ 6.11788685e+00,  8.85809051e-02],
#        [ 4.02144771e+00,  3.78487265e+00],
#        [ 6.57190587e+00,  3.15114355e+00],
#        [ 6.41677968e+00,  3.41925616e+00],
#        [ 3.11944657e+00,  3.07913168e+00],
#        [ 6.21176834e+00,  2.04964608e-01],
#        [ 6.38730446e+00,  4.38826033e+00],
#        [ 6.84891427e+00,  8.50092265e-01],
#        [ 6.45269571e+00,  4.03295109e+00],
#        [ 2.85103978e+00,  2.59391612e+00],
#        [ 6.93090276e+00,  2.01904621e-01],
#        [ 5.75516317e+00,  3.47945323e+00],
#        [ 4.25884654e+00,  2.91500921e-01],
#        [ 4.48549682e+00,  3.53711057e+00],
#        [ 4.17045529e+00,  2.97564768e-01],
#        [ 3.92070065e+00,  1.12317780e+00],
# ...

# %%
plt.scatter(x=my_circle[:, 0], y=my_circle[:, 1], c=my_circle[:, 2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-0f6a0805e085> in <module>
# ----> 1 plt.scatter(x=my_circle[:, 0], y=my_circle[:, 1], c=my_circle[:, 2])
#
# IndexError: index 2 is out of bounds for axis 1 with size 2
